# %%
import numpy, pandas, matplotlib, scipy, statsmodels
print("✅ All packages are installed")
# Out:
# ✅ All packages are installed

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.17
# decorator               5.2.1
# executing               2.2.1
# fonttools               4.61.0
# ipykernel               7.1.0
# ipython                 9.7.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.9.1
# kiwisolver              1.4.9
# matplotlib              3.10.7
# matplotlib-inline       0.2.1
# nest-asyncio            1.6.0
# numpy                   2.3.5
# packaging               25.0
# pandas                  2.3.3
# parso                   0.8.5
# patsy                   1.0.2
# pillow                  12.0.0
# pip                     25.2
# platformdirs            4.5.0
# prompt_toolkit          3.0.52
# psutil                  7.1.3
# pure_eval               0.2.3
# Pygments                2.19.2
# pyparsing               3.2.5
# python-dateutil         2.9.0.post0
# pytz                    2025.2
# pyzmq                   27.1.0
# scipy                   1.16.3
# six                     1.17.0
# stack-data              0.6.3
# statsmodels             0.14.6
# tornado                 6.5.2
# traitlets               5.14.3
# tzdata                  2025.2
# wcwidth                 0.2.14
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy, pandas, scipy, statsmodels

print("numpy:", numpy.__version__)
print("pandas:", pandas.__version__)
print("scipy:", scipy.__version__)
print("statsmodels:", statsmodels.__version__)
# Out:
# numpy: 2.3.5
# pandas: 2.3.3
# scipy: 1.16.3
# statsmodels: 0.14.6
